# %%
from extractor.pdf_extractor import extract_text
import pypdfium2 as pdfium
import pytesseract

# %%
text = extract_text("demo_data/02-PDBMS.pdf")
text
# Out:
# [('Large-Scale Data Management\r\n02 – Parallel and Distributed \r\nDatabase Systems\r\nRainer Gemulla\r\n(Universität Mannheim, HWS 2022)',
#   'Large-Scale Data Management\n02 — Parallel and Distributed\nDatabase Systems\nRainer Gemulla\n(Universitat Mannheim, HWS 2022)\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Outline\r\n1. Basics\r\n2. Fragmentation\r\n3. Allocation\r\n4. Transparency\r\n2',
#   'Outline\n\n1. Basics\n\nBB WN\n\n. Fragmentation\n. Allocation\n. Transparency\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Outline\r\n1. Basics\r\n2. Fragmentation\r\n3. Allocation\r\n4. Transparency\r\n3',
#   'Outline\n\n1. Basics\n2.\n3.\n4.\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Parallel DBMS\r\n• Loosely: DBMS implemented on parallel \r\ncomputer\r\n– Set of nodes (processors, memories, disks)\r\n– Physically close \r\n– Fast network, small communication costs\r\n– Idea: Build powerful computer out of those machines\r\n• Homogenous software\r\n• Goals\r\n– High performance\r\n– High availability\r\n– Extensibility\r\n4',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Extensibility metrics (1)\r\n5\r\nSpeedup Scaleup',
#   'Extensibility metrics (1)\n\noO oO\n2 Ideal e Ideal\noO ©\nE E\n£ =\noO fod)\noO. o\nNb of Nodes Nb of Nodes, DB size\n\nSpeedup Scaleup\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Extensibility metrics (2)\r\n• Elasticity = degree to which system\r\nautonomously adapts capacity (e.g., #nodes) \r\nover time\r\n6',
#   'Extensibility metrics (2)\n\ne Elasticity = degree to which system\nautonomously adapts capacity (e.g., #nodes)\nover time\n\nInfrastructure\nCost\n\nYou just\nlost\n\nc\nLarge ustomers\n\ncapital\nexpenditure\n\nOpportunity\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Parallel DBMS architectures\r\n• Choice of hardware and connectivity has \r\nmajor impact on cost & performance \r\n• Basic architectures\r\n– Shared memory\r\n– Shared disk\r\n– Shared nothing\r\n• Hybrid architectures\r\n– NUMA\r\n– Clusters\r\n7',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Numbers everyone should know\r\n8\r\nL1 cache reference 0.5 ns\r\nBranch mispredict 5 ns\r\nL2 cache reference 7 ns\r\nMutex lock/unlock 25 ns\r\nMain memory reference 100 ns\r\nCompress 1K bytes with Zippy 3,000 ns\r\nSend 2K bytes over 1 Gbps network 20,000 ns\r\nRead 1 MB sequentially from memory 250,000 ns\r\nRound trip within same datacenter 500,000 ns\r\nDisk seek 10,000,000 ns\r\nRead 1 MB sequentially from disk 20,000,000 ns\r\nSend packet CA->Netherlands->CA 150,000,000 ns\r\nDean09',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Shared-memory architecture\r\n• All processors share memory & disk\r\n• Mainframes, SMP\r\n• Good\r\n– Simplicity\r\n– Efficiency\r\n– Load balancing\r\n• Bad\r\n– High cost\r\n– Limited extensibility\r\n– Low availability \r\n9',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Shared-disk architecture\r\n• Memory exclusive, disk shared\r\n• Good\r\n– Lower cost\r\n– Higher extensibility\r\n– Higher availability\r\n– Load balancing\r\n• Bad\r\n– Higher complexity\r\n– Potential performance\r\nproblems\r\n10',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Shared-nothing architecture\r\n• Memory and disk exclusive\r\n• MPP\r\n• Good\r\n– Lower cost\r\n– High extensibility\r\n– High availability\r\n• Cons\r\n– Complexity!!!\r\n11',
#   'Shared-nothing architecture\n\n¢ Memory and disk exclusive\n¢ MPP\n° Good\n— Lower cost\n— High extensibility\n— High availability\n° Cons\n\nInterconnect\n\n— Complexity!!!\n\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Hybrid architectures\r\n• Combinations allow trade-offs\r\n– Cost, performance, extensibility, availability, …\r\n• Example: NUMA\r\n– Roughly: shared memory, \r\nbut varying access costs\r\n– Each node can be SMP\r\n• Example: Cluster\r\n– Set of interconnected server nodes, shared disk or \r\nshared nothing\r\n– Each node: shared memory\r\n12',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example: Oracle Exadata DB Machine\r\n• Up to 912 CPU cores and 28.5TB memory \r\nper rack for database processing\r\n• Up to 576 CPU cores per rack dedicated \r\nto SQL processing in storage\r\n• From 2 to 19 Database Servers per rack\r\n• From 3 to 18 Storage Servers per rack\r\n• Up to 920TB of Flash capacity (raw) per \r\nrack\r\n• Up to 3.0PB of disk capacity (raw) per \r\nrack\r\n• Hybrid Columnar Compression often \r\ndelivers 10X-15X compression ratios\r\n• 40 Gb/second (QDR) InfiniBand Network\r\n• Complete redundancy for high availability\r\n13\r\nOracle Exadata X8-2 Data Sheet',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Distributed DBMS\r\n• Loosely: DBMS implemented on top of multiple \r\nsites that hold their own data\r\n• Sites may be\r\n– Geographically distributed\r\n(slow interconnect, larger communication costs)\r\n– Heterogenous\r\n(different DBMS or even raw data in files)\r\n– Autonomous\r\n(e.g., a DBMS with local clients)\r\n• Goals\r\n– Share distributed data\r\n– Transparent access\r\n– Maintain autonomy of sites (federation, disconnected \r\noperation)\r\n14',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Distributed database\r\n15',
#   'Distributed database\n\nCommunication\nNetwork\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example: Big Data SQL Engines\r\n• Such as Presto or Google F1\r\n• Combine data across multiple sources…\r\n– RDBMS, NoSQL databases, proprietary data stores, \r\nfiles\r\n• … in a single scalable query processing engine\r\n– SQL (all data viewed as tables)\r\n– OLAP (Presto) and partly also OLTP (e.g., F1)\r\n• E.g., Presto @ Facebook (2019): “At Facebook \r\nalone, over a thousand employees use Presto, \r\nrunning several million queries and processing \r\npetabytes of data per day.”\r\n16',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Query processing\r\nTypically:\r\n• Parallel DBMS\r\n– Distribute/partition/sort data to make certain DB \r\noperations fast\r\n• Distributed DBMS\r\n– Data distribution given\r\n– Find query processing strategy to minimize cost\r\n• Still: many similarities\r\n17',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Outline\r\n1. Basics\r\n2. Fragmentation\r\n3. Allocation\r\n4. Transparency\r\n18',
#   'Outline\n\n1.\n2. Fragmentation\n3.\n4.\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Data Placement in PDBMS\r\n• Data placement\r\n– Data at hand\r\n– Need to decide where to put what\r\n• Fragmentation\r\n– Divide the dataset into fragments\r\n– Also called partitioning or sharding\r\n• Allocation\r\n– Decide where to put each fragment\r\n– With or without replication\r\n• Not independent\r\n– But we discuss them separately\r\n19',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Fragmentation and allocation\r\n20 20\r\nR2\r\nR3\r\nR1\r\nR3\r\n3\r\nR2\r\n1\r\nR3\r\n2\r\nR1\r\nR\r\n1\r\nR1\r\n2\r\nR\r\nFragmentation Allocation\r\nSite 1\r\nSite 3\r\nSite 2',
#   'Fragmentation and allocation\n\nFragmentation Allocation\n\nSite 2\n\nSite 3\n\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Overview\r\n21\r\nGlobal schema\r\nFragmentation schema\r\nAllocation schema\r\nLocal\r\nschema\r\nLocal\r\nschema\r\nLocal\r\nDBMS\r\nLocal\r\nDBMS\r\nLocal\r\nDB\r\nLocal\r\nDB\r\nSite 1 Site 2\r\n...\r\n...\r\n...\r\n...',
#   'Overview\n\nGlobal schema\nFragmentation schema\nAllocation schema\n\nLocal Local\nschema schema\n\n| Local! ! Local!\nI I\nL DBMS 1 i DBMS _|\nI I\na —\nLocal Local\nDB DB\n\n21\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Why fragmentation?\r\n• Data distribution viewpoint\r\n– No reason to fragment, just distribute relations\r\n• Why fragmentation then?\r\n– Load balancing\r\n• Entire relation at one site → hot spot\r\n• At multiple sites → increased cost of updates, storage\r\n– Improved efficiency/scalability\r\n• Divide single query into set of subqueries on subrelations\r\n(intra-query parallelism)\r\n• Run multiple queries in parallel (inter-query parallelism)\r\n• Data locality is often key\r\n– Applications often work on subsets of relations\r\n– Reduce communication costs by keeping data items\r\ntogether that are accessed together\r\n22',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('How to fragment?\r\n• Horizontally: fragment = set of tuples\r\n• Vertically: fragment = set of attributes\r\n• Hybrid\r\n23',
#   'How to fragment?\n\n¢ Horizontally: fragment = set of tuples\n\no>\noe\n\n° Vertically: fragment = set of attributes\n\n¢ Hybrid\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example (1)\r\n• Employee relation E(#, name, loc, sal, …)\r\n• Two sites: Sa, Sb\r\n– Qa asked at site Sa\r\n– Qb at site Sb\r\n• What are good fragments?\r\n24\r\n40% of queries 40% of queries\r\nQa: select * \r\nfrom E\r\nwhere location=Sa\r\nand …\r\nQb: select * \r\nfrom E\r\nwhere location=Sb\r\nand …',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example (2)\r\n# name loc sal\r\n5 Joe Sa 10\r\n7 Sally Sb 25\r\n8 Tom Sa 15\r\n…\r\n25\r\n# name loc sal\r\n5 Joe Sa 10\r\n8 Tom Sa 15\r\n…\r\n# name loc sal\r\n7 Sally Sb 25\r\n…\r\nAt Sa At Sb',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example (3)\r\n• Fragment at Sa\r\n– 𝐸1 = 𝜎loc=Sa(𝐸)\r\n• Fragment at Sb\r\n– 𝐸2 = 𝜎loc=Sb\r\n(𝐸)\r\n• Called primary horizontal fragmentation\r\n– Depends on local attributes\r\n– Example of value-based fragmentation: fragments\r\ndetermined by a tuple‘s attribute values\r\n– Generally: 𝑅𝑖 = 𝜎𝑝𝑖\r\n(𝑅)\r\n26',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Correctness requirements\r\n• Completeness\r\n– Every data item in at least one fragment\r\n• Reconstructability\r\n– Construct original data from fragments\r\n– Via a relational operator\r\n• Often also: disjointness\r\n– Each data item in at most one fragment\r\n27',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Correctness of horizontal fragmentation\r\n• Predicates needs to be chosen carefully\r\n• Tuples may be lost\r\n– E.g., 𝜎sal<10(𝐸) and 𝜎sal≥20\r\n(𝐸)\r\n• Tuples may be duplicated\r\n– E.g., 𝜎sal<10(𝐸) and 𝜎sal≥5\r\n(𝐸)\r\n• How to ensure correctness?\r\n– Check manually\r\n– Generate fragments automatically\r\n• Reconstruction via union: 𝑅 =∪𝑖 𝑅𝑖\r\n28',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Common techniques\r\n• Round robin\r\n• Hash partitioning\r\n• Range partitioning\r\n29',
#   'Common techniques\n¢ Round robin\n¢ Hash partitioning\n¢ Range partitioning\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Round robin\r\n• Evenly distributes data\r\n• Good for scanning full relation\r\n• Not good for point or range queries\r\n• Uniqueness constraints difficult to enforce\r\n30\r\nR D0 D1 D2\r\nt1 t1\r\nt2 t2\r\nt3 t3\r\nt4 t4\r\n... t5',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Hash partitioning\r\n• Good for point queries and joins on hash key (not \r\nnecessarily a primary key!)\r\n• Not good for range queries; point queries not on key\r\n• If hash function good and key values not skewed: even \r\ndistribution (exercise)\r\n• Uniqueness easy to handle on key\r\n• May need to move tuple during updates\r\n31\r\nR D0 D1 D2\r\nt1→h(k1)=2 t1\r\nt2→h(k2)=0 t2\r\nt3→h(k3)=0 t3\r\nt4→h(k4)=1 t4\r\n...',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example (Oracle)\r\nCREATE TABLE sales\r\n(salesman_id NUMBER(5), \r\nsalesman_name VARCHAR2(30), \r\nsales_amount NUMBER(10), \r\nweek_no NUMBER(2)) \r\nPARTITION BY HASH(salesman_id) \r\nPARTITIONS 4 \r\nSTORE IN (ts1, ts2, ts3, ts4);\r\n32',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('• Good for point&range queries on partitioning key A\r\n• Need to select good partitioning vector, else imbalance\r\n→ data skew, execution skew\r\n• Uniqueness easy to handle on key\r\n• May need to move tuple during updates\r\n33\r\nR D0 D1 D2\r\nt1: A=5 t1\r\nt2: A=8 t2\r\nt3: A=2 t3\r\nt4: A=3 t4\r\n...\r\n4 7\r\npartitioning\r\nvector\r\nV0 V1\r\nRange partitioning',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ("Example (Oracle)\r\nCREATE TABLE sales\r\n(salesman_id NUMBER(5), \r\nsalesman_name VARCHAR2(30), \r\nsales_amount NUMBER(10), \r\nsales_date DATE)\r\nPARTITION BY RANGE(sales_date) \r\n( PARTITION sales_jan2000 VALUES LESS \r\nTHAN(TO_DATE('02/01/2000','MM/DD/YYYY')),\r\nPARTITION sales_feb2000 VALUES LESS \r\nTHAN(TO_DATE('03/01/2000','MM/DD/YYYY')),\r\nPARTITION sales_mar2000 VALUES LESS \r\nTHAN(TO_DATE('04/01/2000','MM/DD/YYYY')),\r\nPARTITION sales_apr2000 VALUES LESS \r\nTHAN(TO_DATE('05/01/2000','MM/DD/YYYY')));\r\n34",
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Automatically generating fragments\r\n1. Take a set of simple predicates p1\r\n, …, pk\r\n– E.g., p1 \uf0ba sal<10, p2 \uf0ba sal<20\r\n2. Generate all 2k\r\n„minterm“ predicates\r\n– 𝜎𝑝1∧𝑝2\r\n𝑅 , 𝜎𝑝1∧¬𝑝2\r\n𝑅 , 𝜎¬𝑝1∧𝑝2\r\n𝑅 , 𝜎¬𝑝1∧¬𝑝2\r\n𝑅\r\n3. Eliminate “useless” fragments\r\n– 𝜎𝑝1∧𝑝2\r\n𝑅 ≡ 𝜎sal<10 𝑅\r\n– 𝜎𝑝1∧¬𝑝2\r\n𝑅 ≡ ∅\r\n– 𝜎¬𝑝1∧𝑝2\r\n𝑅 ≡ 𝜎10≤sal<20 𝑅\r\n– 𝜎¬𝑝1∧¬𝑝2\r\n𝑅 ≡ 𝜎sal≥20 𝑅\r\n• Gives correct fragments\r\n35',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example continued (1)\r\n• Employee relation E(#, name, loc, sal, …)\r\n– Partitioned by location\r\n• Project relation P(#, des, …)\r\n• Common query for P\r\n– Given employee name, list projects (s)he works in\r\n36',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example continued (2)\r\n37\r\n# des\r\n5 Study LSDM\r\n7 Go to Carnival\r\n8 Build table\r\n12 Rest\r\n…\r\nP\r\n# name loc sal\r\n5 Joe Sa 10\r\n8 Tom Sa 15\r\n…\r\n# name loc sal\r\n7 Sally Sb 25\r\n12 Fred Sb 15\r\n…\r\nE1\r\n(at Sa) E2\r\n(at Sb)',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example continued (3)\r\n38\r\n# name loc sal\r\n5 Joe Sa 10\r\n8 Tom Sa 15\r\n…\r\n# name loc sal\r\n7 Sally Sb 25\r\n12 Fred Sb 15\r\n…\r\nE1\r\n(at Sa) E2\r\n(at Sb)\r\n# des\r\n5 Study LSDM\r\n8 Build table\r\n…\r\nP1\r\n(at Sa)\r\n# des\r\n7 Go to Carnival\r\n12 Rest\r\n…\r\nP2\r\n(at Sb)\r\nHow to construct these partitions?',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Natural join\r\n• Natural join\r\n39\r\nL\r\nA B C\r\na1 b1\r\nc1\r\na2 b2\r\nc2\r\nR\r\nC D E\r\nc1 d1 e1\r\nc3 d2 e2\r\nA =\r\nL A R\r\nA B C D E\r\na1 b1\r\nc1 d1 e1',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Semi joins\r\n• Left semi join of L and R\r\n• Right semi join of L and R\r\n40\r\nL\r\nA B C\r\na1 b1\r\nc1\r\na2 b2\r\nc2\r\nR\r\nC D E\r\nc1 d1 e1\r\nc3 d2 e2\r\nE =\r\nL E R\r\nA B C\r\na1 b1\r\nc1\r\nL\r\nA B C\r\na1 b1\r\nc1\r\na2 b2\r\nc2\r\nR\r\nC D E\r\nc1 d1 e1\r\nc3 d2 e2\r\nF =\r\nL F R\r\nC D E\r\nc1 d1 e1',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example continued (4)\r\n41\r\n# name loc sal\r\n5 Joe Sa 10\r\n8 Tom Sa 15\r\n…\r\n# name loc sal\r\n7 Sally Sb 25\r\n12 Fred Sb 15\r\n…\r\nE1\r\n(at Sa) E2\r\n(at Sb)\r\n# name\r\n5 Study LSDM\r\n8 Build table\r\n…\r\nP1\r\n(at Sa)\r\n# name\r\n7 Go to Carnival\r\n12 Rest\r\n…\r\nP2\r\n(at Sb)\r\nP1 \uf0ba P E E1 P2 \uf0ba P E E2',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Derived horizontal fragmentation\r\n• Given horizontal fragmentation R1\r\n,…,Rn of R\r\n– Primary or derived\r\n• Derived horizontal fragmentation S1\r\n,…,Sn of S\r\n– Si \uf0ba S E Ri\r\n– R called owner, S member\r\n• Completeness\r\n– Need referential integrity\r\n• Disjointness\r\n– Join attribute should be key of owner\r\n• (Common) special case\r\n– R and S have same partitioning rule (on a join attribute)\r\n– We say: R and S are co-partitioned\r\n42',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Vertical fragmentation (example)\r\n43\r\n# name loc sal\r\n5 Joe Sa 10\r\n7 Sally Sb 25\r\n8 Tom Sa 15\r\n…\r\nE2\r\n# name loc\r\n5 Joe Sa\r\n7 Sally Sb\r\n8 Tom Sa\r\n…\r\n# sal\r\n5 10\r\n7 25\r\n8 15\r\n…\r\nE1\r\nE',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Vertical fragmentation\r\n• Relation R[T] fragmented in R[Ti\r\n] with Ti\uf0cdT\r\n• Completeness: ڂ i\r\nTi = T\r\n• Disjointness: Ti \uf0c7 Tj ≠ \uf0c6 for i ≠ j\r\n– E(#,loc,sal) \r\n• One way: repeat primary key in all fragments\r\n– I.e., Key \uf0cd Ti\r\nfor all i\r\n– Reconstruction: Ai R[Ti\r\n] = R\r\n44\r\nE1\r\n(#,loc) \r\nE2\r\n(sal) \r\nNot reconstructible',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Hybrid fragmentation\r\n• Can be represented by a tree\r\n• Reconstruction\r\n45',
#   'Hybrid fragmentation\n\n¢ Can be represented by a tree\n\nR\nte\nRy Ro\nRi Ry2 Raq Roo «Rag\n\n¢ Reconstruction\nU\naa.\n\nRaq R12 Rat Roa Rag\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('How to fragment?\r\n• Information need: database and application\r\ninformation\r\n• Generally: Keep together data items that are\r\nusually accessed together\r\n• E.g., attribute affinity matrix for vertical frag.\r\n46\r\nA1 A2 A3 A4 A5\r\nA1 - - - - -\r\nA2 50 - - - -\r\nA3 45 48 - - -\r\nA4 1 2 0 - -\r\nA5 0 0 4 75 -',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Outline\r\n1. Basics\r\n2. Fragmentation\r\n3. Allocation\r\n4. Transparency\r\n47',
#   'Outline\n1.\n2.\n3. Allocation\n4.\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Allocation example\r\n• Employee relation E(#, name, loc, sal, …)\r\n• Two fragments:\r\n𝐸1 = 𝜎loc=Sa 𝐸 and 𝐸2 = 𝜎loc=Sb\r\n(𝐸)\r\n• Two sites: Sa, Sb\r\n• Where to put fragments E1\r\n, E2\r\n?\r\n48\r\n40% of queries 40% of queries\r\nQa: select * \r\nfrom E\r\nwhere location=Sa\r\nand …\r\nQb: select * \r\nfrom E\r\nwhere location=Sb\r\nand …',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Issues (1)\r\n• What kind of queries?\r\n• Where do queries originate?\r\n• What is the storage capacity and cost at the sites?\r\n– Size of fragments\r\n• What is the processing power at sites?\r\n• What is the communication cost?\r\n– Size of answers, relations, intermediates, …\r\n• What is the query processing strategy?\r\n– How are joins done? Or transactions?\r\n– Where are answers collected?\r\n49',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Issues (2)\r\n• Do we replicate fragments?\r\n– Cost of updating copies\r\n– Concurrency control\r\n50',
#   'Issues (2)\n\n° Do we replicate fragments?\n— Cost of updating copies\n— Concurrency control\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Optimization problem\r\n• What is the best placement and best number of\r\ncopies of each fragment? E.g.,\r\n– Minimize query response time\r\n– Or maximize throughput\r\n– Or minimize „some cost“\r\n– …\r\n• Subject to constraints?\r\n– Available storage\r\n– Available bandwidth, power, …\r\n– Keep 90% of response time below X\r\n– …\r\n• Very hard problem\r\n51',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('A very simple model\r\n• Single fragment F, m sites\r\n• Simple cost model\r\n– ti\r\n: # retrieval queries from site i\r\n– ui\r\n: # update queries from site i\r\n– Processing cost depends only on type of query \r\nand source/target site\r\n• No capacity constraints\r\n– Processing power, storage, …\r\n• Question: Where to store F?\r\n– Set 𝐼 ⊆ 1, … , 𝑚 of sites\r\n52',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Read cost (1)\r\n53\r\nS1 S2\r\n.\r\n. .\r\n.\r\n.\r\n.\r\nS3\r\nSi\r\nCi4\r\nCi3\r\nCi1\r\nCi2\r\nStream of read\r\nrequests for F\r\nti REQ/SEC\r\nCi5\r\nCii\r\nF\r\nF F\r\nS4 S5',
#   'Read cost (1)\n\nfo ~ Si Stream of read\neo requests for F\nCae t; REQ/SEC\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Read cost (2)\r\n• Read where cheapest\r\n• Cost: σ𝑖=1\r\n𝑚 𝑡𝑖 min\r\n𝑗∈𝐼\r\n𝐶𝑖𝑗\r\n– ti\r\n: # retrieval queries from site i\r\n– 𝐶𝑖𝑗: cost of processing one retrieval query from\r\nsite i using replica at site j\r\n54',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Write cost (1)\r\n55\r\nUpdates\r\nui updates/sec\r\n. .\r\n. .\r\n. .\r\nSi\r\nF\r\nF F',
#   'Write cost (1)\n\nF NY Updates\n\nLl] _————__ 8\n\nSj u, updates/sec\n\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Write cost (2)\r\n• Update all replicas\r\n• Cost: σ𝑖=1\r\n𝑚 𝑢𝑖 σ𝑗∈𝐼 𝐶𝑖𝑗\r\n′\r\n– ui\r\n: # update queries from site i\r\n– 𝐶𝑖𝑗\r\n′\r\n: cost of processing one update query from\r\nsite i on replica at site j\r\n56',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Storage cost\r\n• May differ per site\r\n• Cost: σ𝑖∈𝐼 𝑑𝑖\r\n– di\r\n: cost of storing replica at site i\r\n57',
#   'Storage cost\ne May differ per site\n° Cost: Vie, di\n—d;: cost of storing replica at site /\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Putting it together\r\n• Total cost is sum of individual costs\r\n• min\r\n𝐼\r\nσ𝑖=1\r\n𝑚 (𝑡𝑖 min\r\n𝑗∈𝐼\r\n𝐶𝑖𝑗 + 𝑢𝑖 σ𝑗∈𝐼 𝐶𝑖𝑗\r\n′\r\n) + σ𝑖∈𝐼 𝑑𝑖\r\n• Problem is NP-complete…\r\n• … and overly simplified; e.g., in practice\r\n– Multiple fragments, multiple relations\r\n– Fragment placement / costs not independent\r\n– Complex query processing costs \r\n– Cost of integrity enforcement\r\n– Cost of concurrency control\r\n– Dynamics\r\n– ….\r\n58',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Outline\r\n1. Basics\r\n2. Fragmentation\r\n3. Allocation\r\n4. Transparency\r\n59',
#   'Outline\n1.\n2.\n3.\n4. Transparency\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Transparency\r\n• Transparency = separation of high-level \r\nsemantics from implementation\r\n– Hide implementation details from user\r\n– Cf.: data independence in RDBMS\r\n• Multiple layers\r\n– Fragmentation transparency\r\n– Allocation transparency\r\n– Network transparency\r\n60',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Example\r\n# name loc sal\r\n5 Joe Sa 10\r\n7 Sally Sb 25\r\n8 Tom Sa 15\r\n…\r\n61\r\n# name loc sal\r\n5 Joe Sa 10\r\n8 Tom Sa 15\r\n…\r\n# name loc sal\r\n7 Sally Sb 25\r\n…\r\nAt Sa At Sb\r\nE\r\nE1\r\nE2',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Overview\r\n62\r\nGlobal schema\r\nFragmentation schema\r\nAllocation schema\r\nLocal\r\nschema\r\nLocal\r\nschema\r\nLocal\r\nDBMS\r\nLocal\r\nDBMS\r\nLocal\r\nDB\r\nLocal\r\nDB\r\nSite 1 Site 2\r\n...\r\n...\r\n...\r\n...',
#   'Overview\n\nGlobal schema\nFragmentation schema\nAllocation schema\n\nLocal Local\nschema schema\n\n| Local! ! Local!\nI I\nL DBMS 1 i DBMS _|\nI I\na —\nLocal Local\nDB DB\n\n62\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Fragmentation transparency\r\n• Queries placed against global schema\r\n– Fragmentation and allocation hidden\r\n• Example \r\n– select #, loc\r\nfrom E\r\nwhere #=5\r\n63',
#   'Fragmentation transparency\n\n° Queries placed against global schema\n— Fragmentation and allocation hidden\n° Example\n\n— select #, loc\nfrom E\nwhere #=5\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Allocation transparency\r\n• Queries placed against fragmentation schema\r\n– Applications need to know fragmentation and \r\nplace their queries against fragments\r\n– Allocation still hidden\r\n• Example \r\n– select #, loc\r\nfrom E1\r\nwhere #=5\r\n• Example: how many employees?\r\n– select count(*)\r\nfrom E1 union E2\r\n64',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Network transparency\r\n• Queries placed against allocation schema\r\n– Applications need to know fragmentation and place \r\ntheir queries against fragments\r\n– Applications also decide which fragments to use\r\n• Example \r\n– select #, loc\r\nfrom E1 at Sa\r\nwhere #=5\r\n• Still some level of transparency\r\n– Same data model, same query language\r\n– Often not possible when using different DBMS at sites\r\n65',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Layers of independence\r\n66',
#   'Layers of independence\n\n\\ndepengg Ne\nS\n\n66\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Which level of transparency?\r\n• Compromise\r\n– Ease of use\r\n– Stability w.r.t. configuration changes\r\n– Ability to control query processing by applications\r\n– Difficulty and overhead cost of providing \r\ntransparency\r\n• Choice is application dependent\r\n– E.g., full transparency may be poor choice for \r\ngeographically distributed sites\r\n67',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Outline\r\n1. Basics\r\n2. Fragmentation \r\n3. Allocation\r\n4. Transparency\r\n68',
#   'Outline\n\n1. Basics\n\nNO\n\n. Fragmentation\n. Allocation\n. Transparency\n\n W\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Literature\r\n• Ö/V, Principles of Distributed Database Systems\r\n– Ch. 1: Introduction\r\n– Ch. 2: Distributed and Parallel Database Design\r\n– Ch. 8: Parallel Database Systems\r\n• GM/U/W, Database Systems – The Complete\r\nBook\r\n– Ch. 20: Parallel and Distributed Databases\r\n• W, Advanced Data Management\r\n– Ch. 10: Distributed database systems\r\n– Ch. 11: Fragmentation\r\n• K/E, Datenbanksysteme\r\n– Ch. 16: Verteilte Datenbanken\r\n69',
#   '',
#   <PIL.Image.Image image mode=RGB size=1440x1080>),
#  ('Acknowledgements\r\n• Garcia-Molina: Parallel and Distributed Data \r\nManagement\r\n• Kemper: Verteilte Datenbanken\r\n70',
#   'Acknowledgements\n\n¢ Garcia-Molina: Parallel and Distributed Data\nManagement\n¢ Kemper: Verteilte Datenbanken\n',
#   <PIL.Image.Image image mode=RGB size=1440x1080>)]

# %%
pdf = pdfium.PdfDocument("./demo_data/02-PDBMS.pdf")

pages = []
for page_index, page_content in enumerate(pdf, 1):
    page_text: str = page_content.get_textpage().get_text_range()
    page_text = page_text.replace("\r","")
    page_text = page_text.replace("\n","")
    pages.append((page_index, page_text))
pages
# Out:
# [(1,
#   'Large-Scale Data Management02 – Parallel and Distributed Database SystemsRainer Gemulla(Universität Mannheim, HWS 2022)'),
#  (2, 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency2'),
#  (3, 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency3'),
#  (4,
#   'Parallel DBMS• Loosely: DBMS implemented on parallel computer– Set of nodes (processors, memories, disks)– Physically close – Fast network, small communication costs– Idea: Build powerful computer out of those machines• Homogenous software• Goals– High performance– High availability– Extensibility4'),
#  (5, 'Extensibility metrics (1)5Speedup Scaleup'),
#  (6,
#   'Extensibility metrics (2)• Elasticity = degree to which systemautonomously adapts capacity (e.g., #nodes) over time6'),
#  (7,
#   'Parallel DBMS architectures• Choice of hardware and connectivity has major impact on cost & performance • Basic architectures– Shared memory– Shared disk– Shared nothing• Hybrid architectures– NUMA– Clusters7'),
#  (8,
#   'Numbers everyone should know8L1 cache reference 0.5 nsBranch mispredict 5 nsL2 cache reference 7 nsMutex lock/unlock 25 nsMain memory reference 100 nsCompress 1K bytes with Zippy 3,000 nsSend 2K bytes over 1 Gbps network 20,000 nsRead 1 MB sequentially from memory 250,000 nsRound trip within same datacenter 500,000 nsDisk seek 10,000,000 nsRead 1 MB sequentially from disk 20,000,000 nsSend packet CA->Netherlands->CA 150,000,000 nsDean09'),
#  (9,
#   'Shared-memory architecture• All processors share memory & disk• Mainframes, SMP• Good– Simplicity– Efficiency– Load balancing• Bad– High cost– Limited extensibility– Low availability 9'),
#  (10,
#   'Shared-disk architecture• Memory exclusive, disk shared• Good– Lower cost– Higher extensibility– Higher availability– Load balancing• Bad– Higher complexity– Potential performanceproblems10'),
#  (11,
#   'Shared-nothing architecture• Memory and disk exclusive• MPP• Good– Lower cost– High extensibility– High availability• Cons– Complexity!!!11'),
#  (12,
#   'Hybrid architectures• Combinations allow trade-offs– Cost, performance, extensibility, availability, …• Example: NUMA– Roughly: shared memory, but varying access costs– Each node can be SMP• Example: Cluster– Set of interconnected server nodes, shared disk or shared nothing– Each node: shared memory12'),
#  (13,
#   'Example: Oracle Exadata DB Machine• Up to 912 CPU cores and 28.5TB memory per rack for database processing• Up to 576 CPU cores per rack dedicated to SQL processing in storage• From 2 to 19 Database Servers per rack• From 3 to 18 Storage Servers per rack• Up to 920TB of Flash capacity (raw) per rack• Up to 3.0PB of disk capacity (raw) per rack• Hybrid Columnar Compression often delivers 10X-15X compression ratios• 40 Gb/second (QDR) InfiniBand Network• Complete redundancy for high availability13Oracle Exadata X8-2 Data Sheet'),
#  (14,
#   'Distributed DBMS• Loosely: DBMS implemented on top of multiple sites that hold their own data• Sites may be– Geographically distributed(slow interconnect, larger communication costs)– Heterogenous(different DBMS or even raw data in files)– Autonomous(e.g., a DBMS with local clients)• Goals– Share distributed data– Transparent access– Maintain autonomy of sites (federation, disconnected operation)14'),
#  (15, 'Distributed database15'),
#  (16,
#   'Example: Big Data SQL Engines• Such as Presto or Google F1• Combine data across multiple sources…– RDBMS, NoSQL databases, proprietary data stores, files• … in a single scalable query processing engine– SQL (all data viewed as tables)– OLAP (Presto) and partly also OLTP (e.g., F1)• E.g., Presto @ Facebook (2019): “At Facebook alone, over a thousand employees use Presto, running several million queries and processing petabytes of data per day.”16'),
#  (17,
#   'Query processingTypically:• Parallel DBMS– Distribute/partition/sort data to make certain DB operations fast• Distributed DBMS– Data distribution given– Find query processing strategy to minimize cost• Still: many similarities17'),
#  (18, 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency18'),
#  (19,
#   'Data Placement in PDBMS• Data placement– Data at hand– Need to decide where to put what• Fragmentation– Divide the dataset into fragments– Also called partitioning or sharding• Allocation– Decide where to put each fragment– With or without replication• Not independent– But we discuss them separately19'),
#  (20,
#   'Fragmentation and allocation20 20R2R3R1R33R21R32R1R1R12RFragmentation AllocationSite 1Site 3Site 2'),
#  (21,
#   'Overview21Global schemaFragmentation schemaAllocation schemaLocalschemaLocalschemaLocalDBMSLocalDBMSLocalDBLocalDBSite 1 Site 2............'),
#  (22,
#   'Why fragmentation?• Data distribution viewpoint– No reason to fragment, just distribute relations• Why fragmentation then?– Load balancing• Entire relation at one site → hot spot• At multiple sites → increased cost of updates, storage– Improved efficiency/scalability• Divide single query into set of subqueries on subrelations(intra-query parallelism)• Run multiple queries in parallel (inter-query parallelism)• Data locality is often key– Applications often work on subsets of relations– Reduce communication costs by keeping data itemstogether that are accessed together22'),
#  (23,
#   'How to fragment?• Horizontally: fragment = set of tuples• Vertically: fragment = set of attributes• Hybrid23'),
#  (24,
#   'Example (1)• Employee relation E(#, name, loc, sal, …)• Two sites: Sa, Sb– Qa asked at site Sa– Qb at site Sb• What are good fragments?2440% of queries 40% of queriesQa: select * from Ewhere location=Saand …Qb: select * from Ewhere location=Sband …'),
#  (25,
#   'Example (2)# name loc sal5 Joe Sa 107 Sally Sb 258 Tom Sa 15…25# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 25…At Sa At Sb'),
#  (26,
#   'Example (3)• Fragment at Sa– 𝐸1 = 𝜎loc=Sa(𝐸)• Fragment at Sb– 𝐸2 = 𝜎loc=Sb(𝐸)• Called primary horizontal fragmentation– Depends on local attributes– Example of value-based fragmentation: fragmentsdetermined by a tuple‘s attribute values– Generally: 𝑅𝑖 = 𝜎𝑝𝑖(𝑅)26'),
#  (27,
#   'Correctness requirements• Completeness– Every data item in at least one fragment• Reconstructability– Construct original data from fragments– Via a relational operator• Often also: disjointness– Each data item in at most one fragment27'),
#  (28,
#   'Correctness of horizontal fragmentation• Predicates needs to be chosen carefully• Tuples may be lost– E.g., 𝜎sal<10(𝐸) and 𝜎sal≥20(𝐸)• Tuples may be duplicated– E.g., 𝜎sal<10(𝐸) and 𝜎sal≥5(𝐸)• How to ensure correctness?– Check manually– Generate fragments automatically• Reconstruction via union: 𝑅 =∪𝑖 𝑅𝑖28'),
#  (29,
#   'Common techniques• Round robin• Hash partitioning• Range partitioning29'),
#  (30,
#   'Round robin• Evenly distributes data• Good for scanning full relation• Not good for point or range queries• Uniqueness constraints difficult to enforce30R D0 D1 D2t1 t1t2 t2t3 t3t4 t4... t5'),
#  (31,
#   'Hash partitioning• Good for point queries and joins on hash key (not necessarily a primary key!)• Not good for range queries; point queries not on key• If hash function good and key values not skewed: even distribution (exercise)• Uniqueness easy to handle on key• May need to move tuple during updates31R D0 D1 D2t1→h(k1)=2 t1t2→h(k2)=0 t2t3→h(k3)=0 t3t4→h(k4)=1 t4...'),
#  (32,
#   'Example (Oracle)CREATE TABLE sales(salesman_id NUMBER(5), salesman_name VARCHAR2(30), sales_amount NUMBER(10), week_no NUMBER(2)) PARTITION BY HASH(salesman_id) PARTITIONS 4 STORE IN (ts1, ts2, ts3, ts4);32'),
#  (33,
#   '• Good for point&range queries on partitioning key A• Need to select good partitioning vector, else imbalance→ data skew, execution skew• Uniqueness easy to handle on key• May need to move tuple during updates33R D0 D1 D2t1: A=5 t1t2: A=8 t2t3: A=2 t3t4: A=3 t4...4 7partitioningvectorV0 V1Range partitioning'),
#  (34,
#   "Example (Oracle)CREATE TABLE sales(salesman_id NUMBER(5), salesman_name VARCHAR2(30), sales_amount NUMBER(10), sales_date DATE)PARTITION BY RANGE(sales_date) ( PARTITION sales_jan2000 VALUES LESS THAN(TO_DATE('02/01/2000','MM/DD/YYYY')),PARTITION sales_feb2000 VALUES LESS THAN(TO_DATE('03/01/2000','MM/DD/YYYY')),PARTITION sales_mar2000 VALUES LESS THAN(TO_DATE('04/01/2000','MM/DD/YYYY')),PARTITION sales_apr2000 VALUES LESS THAN(TO_DATE('05/01/2000','MM/DD/YYYY')));34"),
#  (35,
#   'Automatically generating fragments1. Take a set of simple predicates p1, …, pk– E.g., p1 \uf0ba sal<10, p2 \uf0ba sal<202. Generate all 2k„minterm“ predicates– 𝜎𝑝1∧𝑝2𝑅 , 𝜎𝑝1∧¬𝑝2𝑅 , 𝜎¬𝑝1∧𝑝2𝑅 , 𝜎¬𝑝1∧¬𝑝2𝑅3. Eliminate “useless” fragments– 𝜎𝑝1∧𝑝2𝑅 ≡ 𝜎sal<10 𝑅– 𝜎𝑝1∧¬𝑝2𝑅 ≡ ∅– 𝜎¬𝑝1∧𝑝2𝑅 ≡ 𝜎10≤sal<20 𝑅– 𝜎¬𝑝1∧¬𝑝2𝑅 ≡ 𝜎sal≥20 𝑅• Gives correct fragments35'),
#  (36,
#   'Example continued (1)• Employee relation E(#, name, loc, sal, …)– Partitioned by location• Project relation P(#, des, …)• Common query for P– Given employee name, list projects (s)he works in36'),
#  (37,
#   'Example continued (2)37# des5 Study LSDM7 Go to Carnival8 Build table12 Rest…P# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 2512 Fred Sb 15…E1(at Sa) E2(at Sb)'),
#  (38,
#   'Example continued (3)38# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 2512 Fred Sb 15…E1(at Sa) E2(at Sb)# des5 Study LSDM8 Build table…P1(at Sa)# des7 Go to Carnival12 Rest…P2(at Sb)How to construct these partitions?'),
#  (39,
#   'Natural join• Natural join39LA B Ca1 b1c1a2 b2c2RC D Ec1 d1 e1c3 d2 e2A =L A RA B C D Ea1 b1c1 d1 e1'),
#  (40,
#   'Semi joins• Left semi join of L and R• Right semi join of L and R40LA B Ca1 b1c1a2 b2c2RC D Ec1 d1 e1c3 d2 e2E =L E RA B Ca1 b1c1LA B Ca1 b1c1a2 b2c2RC D Ec1 d1 e1c3 d2 e2F =L F RC D Ec1 d1 e1'),
#  (41,
#   'Example continued (4)41# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 2512 Fred Sb 15…E1(at Sa) E2(at Sb)# name5 Study LSDM8 Build table…P1(at Sa)# name7 Go to Carnival12 Rest…P2(at Sb)P1 \uf0ba P E E1 P2 \uf0ba P E E2'),
#  (42,
#   'Derived horizontal fragmentation• Given horizontal fragmentation R1,…,Rn of R– Primary or derived• Derived horizontal fragmentation S1,…,Sn of S– Si \uf0ba S E Ri– R called owner, S member• Completeness– Need referential integrity• Disjointness– Join attribute should be key of owner• (Common) special case– R and S have same partitioning rule (on a join attribute)– We say: R and S are co-partitioned42'),
#  (43,
#   'Vertical fragmentation (example)43# name loc sal5 Joe Sa 107 Sally Sb 258 Tom Sa 15…E2# name loc5 Joe Sa7 Sally Sb8 Tom Sa…# sal5 107 258 15…E1E'),
#  (44,
#   'Vertical fragmentation• Relation R[T] fragmented in R[Ti] with Ti\uf0cdT• Completeness: ڂ iTi = T• Disjointness: Ti \uf0c7 Tj ≠ \uf0c6 for i ≠ j– E(#,loc,sal) • One way: repeat primary key in all fragments– I.e., Key \uf0cd Tifor all i– Reconstruction: Ai R[Ti] = R44E1(#,loc) E2(sal) Not reconstructible'),
#  (45, 'Hybrid fragmentation• Can be represented by a tree• Reconstruction45'),
#  (46,
#   'How to fragment?• Information need: database and applicationinformation• Generally: Keep together data items that areusually accessed together• E.g., attribute affinity matrix for vertical frag.46A1 A2 A3 A4 A5A1 - - - - -A2 50 - - - -A3 45 48 - - -A4 1 2 0 - -A5 0 0 4 75 -'),
#  (47, 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency47'),
#  (48,
#   'Allocation example• Employee relation E(#, name, loc, sal, …)• Two fragments:𝐸1 = 𝜎loc=Sa 𝐸 and 𝐸2 = 𝜎loc=Sb(𝐸)• Two sites: Sa, Sb• Where to put fragments E1, E2?4840% of queries 40% of queriesQa: select * from Ewhere location=Saand …Qb: select * from Ewhere location=Sband …'),
#  (49,
#   'Issues (1)• What kind of queries?• Where do queries originate?• What is the storage capacity and cost at the sites?– Size of fragments• What is the processing power at sites?• What is the communication cost?– Size of answers, relations, intermediates, …• What is the query processing strategy?– How are joins done? Or transactions?– Where are answers collected?49'),
#  (50,
#   'Issues (2)• Do we replicate fragments?– Cost of updating copies– Concurrency control50'),
#  (51,
#   'Optimization problem• What is the best placement and best number ofcopies of each fragment? E.g.,– Minimize query response time– Or maximize throughput– Or minimize „some cost“– …• Subject to constraints?– Available storage– Available bandwidth, power, …– Keep 90% of response time below X– …• Very hard problem51'),
#  (52,
#   'A very simple model• Single fragment F, m sites• Simple cost model– ti: # retrieval queries from site i– ui: # update queries from site i– Processing cost depends only on type of query and source/target site• No capacity constraints– Processing power, storage, …• Question: Where to store F?– Set 𝐼 ⊆ 1, … , 𝑚 of sites52'),
#  (53,
#   'Read cost (1)53S1 S2.. ....S3SiCi4Ci3Ci1Ci2Stream of readrequests for Fti REQ/SECCi5CiiFF FS4 S5'),
#  (54,
#   'Read cost (2)• Read where cheapest• Cost: σ𝑖=1𝑚 𝑡𝑖 min𝑗∈𝐼𝐶𝑖𝑗– ti: # retrieval queries from site i– 𝐶𝑖𝑗: cost of processing one retrieval query fromsite i using replica at site j54'),
#  (55, 'Write cost (1)55Updatesui updates/sec. .. .. .SiFF F'),
#  (56,
#   'Write cost (2)• Update all replicas• Cost: σ𝑖=1𝑚 𝑢𝑖 σ𝑗∈𝐼 𝐶𝑖𝑗′– ui: # update queries from site i– 𝐶𝑖𝑗′: cost of processing one update query fromsite i on replica at site j56'),
#  (57,
#   'Storage cost• May differ per site• Cost: σ𝑖∈𝐼 𝑑𝑖– di: cost of storing replica at site i57'),
#  (58,
#   'Putting it together• Total cost is sum of individual costs• min𝐼σ𝑖=1𝑚 (𝑡𝑖 min𝑗∈𝐼𝐶𝑖𝑗 + 𝑢𝑖 σ𝑗∈𝐼 𝐶𝑖𝑗′) + σ𝑖∈𝐼 𝑑𝑖• Problem is NP-complete…• … and overly simplified; e.g., in practice– Multiple fragments, multiple relations– Fragment placement / costs not independent– Complex query processing costs – Cost of integrity enforcement– Cost of concurrency control– Dynamics– ….58'),
#  (59, 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency59'),
#  (60,
#   'Transparency• Transparency = separation of high-level semantics from implementation– Hide implementation details from user– Cf.: data independence in RDBMS• Multiple layers– Fragmentation transparency– Allocation transparency– Network transparency60'),
#  (61,
#   'Example# name loc sal5 Joe Sa 107 Sally Sb 258 Tom Sa 15…61# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 25…At Sa At SbEE1E2'),
#  (62,
#   'Overview62Global schemaFragmentation schemaAllocation schemaLocalschemaLocalschemaLocalDBMSLocalDBMSLocalDBLocalDBSite 1 Site 2............'),
#  (63,
#   'Fragmentation transparency• Queries placed against global schema– Fragmentation and allocation hidden• Example – select #, locfrom Ewhere #=563'),
#  (64,
#   'Allocation transparency• Queries placed against fragmentation schema– Applications need to know fragmentation and place their queries against fragments– Allocation still hidden• Example – select #, locfrom E1where #=5• Example: how many employees?– select count(*)from E1 union E264'),
#  (65,
#   'Network transparency• Queries placed against allocation schema– Applications need to know fragmentation and place their queries against fragments– Applications also decide which fragments to use• Example – select #, locfrom E1 at Sawhere #=5• Still some level of transparency– Same data model, same query language– Often not possible when using different DBMS at sites65'),
#  (66, 'Layers of independence66'),
#  (67,
#   'Which level of transparency?• Compromise– Ease of use– Stability w.r.t. configuration changes– Ability to control query processing by applications– Difficulty and overhead cost of providing transparency• Choice is application dependent– E.g., full transparency may be poor choice for geographically distributed sites67'),
#  (68, 'Outline1. Basics2. Fragmentation 3. Allocation4. Transparency68'),
#  (69,
#   'Literature• Ö/V, Principles of Distributed Database Systems– Ch. 1: Introduction– Ch. 2: Distributed and Parallel Database Design– Ch. 8: Parallel Database Systems• GM/U/W, Database Systems – The CompleteBook– Ch. 20: Parallel and Distributed Databases• W, Advanced Data Management– Ch. 10: Distributed database systems– Ch. 11: Fragmentation• K/E, Datenbanksysteme– Ch. 16: Verteilte Datenbanken69'),
#  (70,
#   'Acknowledgements• Garcia-Molina: Parallel and Distributed Data Management• Kemper: Verteilte Datenbanken70')]

# %%
pdf = pdfium.PdfDocument("./demo_data/02-PDBMS.pdf")

pages = []

def ocr_extraction(page: pdfium.PdfPage):
    bitmap = page.render(scale = 2) #sacle=2 to increase resolution
    pil_image = bitmap.to_pil()
    text = pytesseract.image_to_string(pil_image, lang="eng000")
    return text

for page_index, page_content in enumerate(pdf, 1):
    page_text: str = page_content.get_textpage().get_text_range()
    page_text = page_text.replace("\r","")
    page_text = page_text.replace("\n","")
    if len(page_text.split(" ")) > 20:
        pages.append((page_index, page_text))
    else:
        ocr_text = ocr_extraction(page_content)
        pages.append((str(page_index)+"PLAIN", page_text))
        pages.append((str(page_index)+"OCR", ocr_text))

pages
# Out:
# [('1PLAIN',
#   'Large-Scale Data Management02 – Parallel and Distributed Database SystemsRainer Gemulla(Universität Mannheim, HWS 2022)'),
#  ('1OCR',
#   'Large-Scale Data Management\n02 — Parallel and Distributed\nDatabase Systems\nRainer Gemulla\n(Universitat Mannheim, HWS 2022)\n'),
#  ('2PLAIN', 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency2'),
#  ('2OCR',
#   'Outline\n\n1. Basics\n\nBB WN\n\n. Fragmentation\n. Allocation\n. Transparency\n'),
#  ('3PLAIN', 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency3'),
#  ('3OCR', 'Outline\n\n1. Basics\n2.\n3.\n4.\n'),
#  (4,
#   'Parallel DBMS• Loosely: DBMS implemented on parallel computer– Set of nodes (processors, memories, disks)– Physically close – Fast network, small communication costs– Idea: Build powerful computer out of those machines• Homogenous software• Goals– High performance– High availability– Extensibility4'),
#  ('5PLAIN', 'Extensibility metrics (1)5Speedup Scaleup'),
#  ('5OCR',
#   'Extensibility metrics (1)\n\noO oO\n2 Ideal e Ideal\noO ©\nE E\n£ =\noO fod)\noO. o\nNb of Nodes Nb of Nodes, DB size\n\nSpeedup Scaleup\n'),
#  ('6PLAIN',
#   'Extensibility metrics (2)• Elasticity = degree to which systemautonomously adapts capacity (e.g., #nodes) over time6'),
#  ('6OCR',
#   'Extensibility metrics (2)\n\ne Elasticity = degree to which system\nautonomously adapts capacity (e.g., #nodes)\nover time\n\nInfrastructure\nCost\n\nYou just\nlost\n\nc\nLarge ustomers\n\ncapital\nexpenditure\n\nOpportunity\n'),
#  (7,
#   'Parallel DBMS architectures• Choice of hardware and connectivity has major impact on cost & performance • Basic architectures– Shared memory– Shared disk– Shared nothing• Hybrid architectures– NUMA– Clusters7'),
#  (8,
#   'Numbers everyone should know8L1 cache reference 0.5 nsBranch mispredict 5 nsL2 cache reference 7 nsMutex lock/unlock 25 nsMain memory reference 100 nsCompress 1K bytes with Zippy 3,000 nsSend 2K bytes over 1 Gbps network 20,000 nsRead 1 MB sequentially from memory 250,000 nsRound trip within same datacenter 500,000 nsDisk seek 10,000,000 nsRead 1 MB sequentially from disk 20,000,000 nsSend packet CA->Netherlands->CA 150,000,000 nsDean09'),
#  (9,
#   'Shared-memory architecture• All processors share memory & disk• Mainframes, SMP• Good– Simplicity– Efficiency– Load balancing• Bad– High cost– Limited extensibility– Low availability 9'),
#  ('10PLAIN',
#   'Shared-disk architecture• Memory exclusive, disk shared• Good– Lower cost– Higher extensibility– Higher availability– Load balancing• Bad– Higher complexity– Potential performanceproblems10'),
#  ('10OCR',
#   'Shared-disk architecture\n\n¢ Memory exclusive, disk shared\n° Good\n— Lower cost\n— Higher extensibility\n— Higher availability\n— Load balancing\n° Bad\n— Higher complexity\n\n— Potential performance\nproblems\n'),
#  ('11PLAIN',
#   'Shared-nothing architecture• Memory and disk exclusive• MPP• Good– Lower cost– High extensibility– High availability• Cons– Complexity!!!11'),
#  ('11OCR',
#   'Shared-nothing architecture\n\n¢ Memory and disk exclusive\n¢ MPP\n° Good\n— Lower cost\n— High extensibility\n— High availability\n° Cons\n\nInterconnect\n\n— Complexity!!!\n\n'),
#  (12,
#   'Hybrid architectures• Combinations allow trade-offs– Cost, performance, extensibility, availability, …• Example: NUMA– Roughly: shared memory, but varying access costs– Each node can be SMP• Example: Cluster– Set of interconnected server nodes, shared disk or shared nothing– Each node: shared memory12'),
#  (13,
#   'Example: Oracle Exadata DB Machine• Up to 912 CPU cores and 28.5TB memory per rack for database processing• Up to 576 CPU cores per rack dedicated to SQL processing in storage• From 2 to 19 Database Servers per rack• From 3 to 18 Storage Servers per rack• Up to 920TB of Flash capacity (raw) per rack• Up to 3.0PB of disk capacity (raw) per rack• Hybrid Columnar Compression often delivers 10X-15X compression ratios• 40 Gb/second (QDR) InfiniBand Network• Complete redundancy for high availability13Oracle Exadata X8-2 Data Sheet'),
#  (14,
#   'Distributed DBMS• Loosely: DBMS implemented on top of multiple sites that hold their own data• Sites may be– Geographically distributed(slow interconnect, larger communication costs)– Heterogenous(different DBMS or even raw data in files)– Autonomous(e.g., a DBMS with local clients)• Goals– Share distributed data– Transparent access– Maintain autonomy of sites (federation, disconnected operation)14'),
#  ('15PLAIN', 'Distributed database15'),
#  ('15OCR', 'Distributed database\n\nCommunication\nNetwork\n'),
#  (16,
#   'Example: Big Data SQL Engines• Such as Presto or Google F1• Combine data across multiple sources…– RDBMS, NoSQL databases, proprietary data stores, files• … in a single scalable query processing engine– SQL (all data viewed as tables)– OLAP (Presto) and partly also OLTP (e.g., F1)• E.g., Presto @ Facebook (2019): “At Facebook alone, over a thousand employees use Presto, running several million queries and processing petabytes of data per day.”16'),
#  (17,
#   'Query processingTypically:• Parallel DBMS– Distribute/partition/sort data to make certain DB operations fast• Distributed DBMS– Data distribution given– Find query processing strategy to minimize cost• Still: many similarities17'),
#  ('18PLAIN', 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency18'),
#  ('18OCR', 'Outline\n\n1.\n2. Fragmentation\n3.\n4.\n'),
#  (19,
#   'Data Placement in PDBMS• Data placement– Data at hand– Need to decide where to put what• Fragmentation– Divide the dataset into fragments– Also called partitioning or sharding• Allocation– Decide where to put each fragment– With or without replication• Not independent– But we discuss them separately19'),
#  ('20PLAIN',
#   'Fragmentation and allocation20 20R2R3R1R33R21R32R1R1R12RFragmentation AllocationSite 1Site 3Site 2'),
#  ('20OCR',
#   'Fragmentation and allocation\n\nFragmentation Allocation\n\nSite 2\n\nSite 3\n\n'),
#  ('21PLAIN',
#   'Overview21Global schemaFragmentation schemaAllocation schemaLocalschemaLocalschemaLocalDBMSLocalDBMSLocalDBLocalDBSite 1 Site 2............'),
#  ('21OCR',
#   'Overview\n\nGlobal schema\nFragmentation schema\nAllocation schema\n\nLocal Local\nschema schema\n\n| Local! ! Local!\nI I\nL DBMS 1 i DBMS _|\nI I\na —\nLocal Local\nDB DB\n\n21\n'),
#  (22,
#   'Why fragmentation?• Data distribution viewpoint– No reason to fragment, just distribute relations• Why fragmentation then?– Load balancing• Entire relation at one site → hot spot• At multiple sites → increased cost of updates, storage– Improved efficiency/scalability• Divide single query into set of subqueries on subrelations(intra-query parallelism)• Run multiple queries in parallel (inter-query parallelism)• Data locality is often key– Applications often work on subsets of relations– Reduce communication costs by keeping data itemstogether that are accessed together22'),
#  ('23PLAIN',
#   'How to fragment?• Horizontally: fragment = set of tuples• Vertically: fragment = set of attributes• Hybrid23'),
#  ('23OCR',
#   'How to fragment?\n\n¢ Horizontally: fragment = set of tuples\n\no>\noe\n\n° Vertically: fragment = set of attributes\n\n¢ Hybrid\n'),
#  (24,
#   'Example (1)• Employee relation E(#, name, loc, sal, …)• Two sites: Sa, Sb– Qa asked at site Sa– Qb at site Sb• What are good fragments?2440% of queries 40% of queriesQa: select * from Ewhere location=Saand …Qb: select * from Ewhere location=Sband …'),
#  (25,
#   'Example (2)# name loc sal5 Joe Sa 107 Sally Sb 258 Tom Sa 15…25# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 25…At Sa At Sb'),
#  (26,
#   'Example (3)• Fragment at Sa– 𝐸1 = 𝜎loc=Sa(𝐸)• Fragment at Sb– 𝐸2 = 𝜎loc=Sb(𝐸)• Called primary horizontal fragmentation– Depends on local attributes– Example of value-based fragmentation: fragmentsdetermined by a tuple‘s attribute values– Generally: 𝑅𝑖 = 𝜎𝑝𝑖(𝑅)26'),
#  (27,
#   'Correctness requirements• Completeness– Every data item in at least one fragment• Reconstructability– Construct original data from fragments– Via a relational operator• Often also: disjointness– Each data item in at most one fragment27'),
#  (28,
#   'Correctness of horizontal fragmentation• Predicates needs to be chosen carefully• Tuples may be lost– E.g., 𝜎sal<10(𝐸) and 𝜎sal≥20(𝐸)• Tuples may be duplicated– E.g., 𝜎sal<10(𝐸) and 𝜎sal≥5(𝐸)• How to ensure correctness?– Check manually– Generate fragments automatically• Reconstruction via union: 𝑅 =∪𝑖 𝑅𝑖28'),
#  ('29PLAIN',
#   'Common techniques• Round robin• Hash partitioning• Range partitioning29'),
#  ('29OCR',
#   'Common techniques\n¢ Round robin\n¢ Hash partitioning\n¢ Range partitioning\n'),
#  (30,
#   'Round robin• Evenly distributes data• Good for scanning full relation• Not good for point or range queries• Uniqueness constraints difficult to enforce30R D0 D1 D2t1 t1t2 t2t3 t3t4 t4... t5'),
#  (31,
#   'Hash partitioning• Good for point queries and joins on hash key (not necessarily a primary key!)• Not good for range queries; point queries not on key• If hash function good and key values not skewed: even distribution (exercise)• Uniqueness easy to handle on key• May need to move tuple during updates31R D0 D1 D2t1→h(k1)=2 t1t2→h(k2)=0 t2t3→h(k3)=0 t3t4→h(k4)=1 t4...'),
#  (32,
#   'Example (Oracle)CREATE TABLE sales(salesman_id NUMBER(5), salesman_name VARCHAR2(30), sales_amount NUMBER(10), week_no NUMBER(2)) PARTITION BY HASH(salesman_id) PARTITIONS 4 STORE IN (ts1, ts2, ts3, ts4);32'),
#  (33,
#   '• Good for point&range queries on partitioning key A• Need to select good partitioning vector, else imbalance→ data skew, execution skew• Uniqueness easy to handle on key• May need to move tuple during updates33R D0 D1 D2t1: A=5 t1t2: A=8 t2t3: A=2 t3t4: A=3 t4...4 7partitioningvectorV0 V1Range partitioning'),
#  (34,
#   "Example (Oracle)CREATE TABLE sales(salesman_id NUMBER(5), salesman_name VARCHAR2(30), sales_amount NUMBER(10), sales_date DATE)PARTITION BY RANGE(sales_date) ( PARTITION sales_jan2000 VALUES LESS THAN(TO_DATE('02/01/2000','MM/DD/YYYY')),PARTITION sales_feb2000 VALUES LESS THAN(TO_DATE('03/01/2000','MM/DD/YYYY')),PARTITION sales_mar2000 VALUES LESS THAN(TO_DATE('04/01/2000','MM/DD/YYYY')),PARTITION sales_apr2000 VALUES LESS THAN(TO_DATE('05/01/2000','MM/DD/YYYY')));34"),
#  (35,
#   'Automatically generating fragments1. Take a set of simple predicates p1, …, pk– E.g., p1 \uf0ba sal<10, p2 \uf0ba sal<202. Generate all 2k„minterm“ predicates– 𝜎𝑝1∧𝑝2𝑅 , 𝜎𝑝1∧¬𝑝2𝑅 , 𝜎¬𝑝1∧𝑝2𝑅 , 𝜎¬𝑝1∧¬𝑝2𝑅3. Eliminate “useless” fragments– 𝜎𝑝1∧𝑝2𝑅 ≡ 𝜎sal<10 𝑅– 𝜎𝑝1∧¬𝑝2𝑅 ≡ ∅– 𝜎¬𝑝1∧𝑝2𝑅 ≡ 𝜎10≤sal<20 𝑅– 𝜎¬𝑝1∧¬𝑝2𝑅 ≡ 𝜎sal≥20 𝑅• Gives correct fragments35'),
#  (36,
#   'Example continued (1)• Employee relation E(#, name, loc, sal, …)– Partitioned by location• Project relation P(#, des, …)• Common query for P– Given employee name, list projects (s)he works in36'),
#  (37,
#   'Example continued (2)37# des5 Study LSDM7 Go to Carnival8 Build table12 Rest…P# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 2512 Fred Sb 15…E1(at Sa) E2(at Sb)'),
#  (38,
#   'Example continued (3)38# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 2512 Fred Sb 15…E1(at Sa) E2(at Sb)# des5 Study LSDM8 Build table…P1(at Sa)# des7 Go to Carnival12 Rest…P2(at Sb)How to construct these partitions?'),
#  (39,
#   'Natural join• Natural join39LA B Ca1 b1c1a2 b2c2RC D Ec1 d1 e1c3 d2 e2A =L A RA B C D Ea1 b1c1 d1 e1'),
#  (40,
#   'Semi joins• Left semi join of L and R• Right semi join of L and R40LA B Ca1 b1c1a2 b2c2RC D Ec1 d1 e1c3 d2 e2E =L E RA B Ca1 b1c1LA B Ca1 b1c1a2 b2c2RC D Ec1 d1 e1c3 d2 e2F =L F RC D Ec1 d1 e1'),
#  (41,
#   'Example continued (4)41# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 2512 Fred Sb 15…E1(at Sa) E2(at Sb)# name5 Study LSDM8 Build table…P1(at Sa)# name7 Go to Carnival12 Rest…P2(at Sb)P1 \uf0ba P E E1 P2 \uf0ba P E E2'),
#  (42,
#   'Derived horizontal fragmentation• Given horizontal fragmentation R1,…,Rn of R– Primary or derived• Derived horizontal fragmentation S1,…,Sn of S– Si \uf0ba S E Ri– R called owner, S member• Completeness– Need referential integrity• Disjointness– Join attribute should be key of owner• (Common) special case– R and S have same partitioning rule (on a join attribute)– We say: R and S are co-partitioned42'),
#  (43,
#   'Vertical fragmentation (example)43# name loc sal5 Joe Sa 107 Sally Sb 258 Tom Sa 15…E2# name loc5 Joe Sa7 Sally Sb8 Tom Sa…# sal5 107 258 15…E1E'),
#  (44,
#   'Vertical fragmentation• Relation R[T] fragmented in R[Ti] with Ti\uf0cdT• Completeness: ڂ iTi = T• Disjointness: Ti \uf0c7 Tj ≠ \uf0c6 for i ≠ j– E(#,loc,sal) • One way: repeat primary key in all fragments– I.e., Key \uf0cd Tifor all i– Reconstruction: Ai R[Ti] = R44E1(#,loc) E2(sal) Not reconstructible'),
#  ('45PLAIN',
#   'Hybrid fragmentation• Can be represented by a tree• Reconstruction45'),
#  ('45OCR',
#   'Hybrid fragmentation\n\n¢ Can be represented by a tree\n\nR\nte\nRy Ro\nRi Ry2 Raq Roo «Rag\n\n¢ Reconstruction\nU\naa.\n\nRaq R12 Rat Roa Rag\n'),
#  (46,
#   'How to fragment?• Information need: database and applicationinformation• Generally: Keep together data items that areusually accessed together• E.g., attribute affinity matrix for vertical frag.46A1 A2 A3 A4 A5A1 - - - - -A2 50 - - - -A3 45 48 - - -A4 1 2 0 - -A5 0 0 4 75 -'),
#  ('47PLAIN', 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency47'),
#  ('47OCR', 'Outline\n1.\n2.\n3. Allocation\n4.\n'),
#  (48,
#   'Allocation example• Employee relation E(#, name, loc, sal, …)• Two fragments:𝐸1 = 𝜎loc=Sa 𝐸 and 𝐸2 = 𝜎loc=Sb(𝐸)• Two sites: Sa, Sb• Where to put fragments E1, E2?4840% of queries 40% of queriesQa: select * from Ewhere location=Saand …Qb: select * from Ewhere location=Sband …'),
#  (49,
#   'Issues (1)• What kind of queries?• Where do queries originate?• What is the storage capacity and cost at the sites?– Size of fragments• What is the processing power at sites?• What is the communication cost?– Size of answers, relations, intermediates, …• What is the query processing strategy?– How are joins done? Or transactions?– Where are answers collected?49'),
#  ('50PLAIN',
#   'Issues (2)• Do we replicate fragments?– Cost of updating copies– Concurrency control50'),
#  ('50OCR',
#   'Issues (2)\n\n° Do we replicate fragments?\n— Cost of updating copies\n— Concurrency control\n'),
#  (51,
#   'Optimization problem• What is the best placement and best number ofcopies of each fragment? E.g.,– Minimize query response time– Or maximize throughput– Or minimize „some cost“– …• Subject to constraints?– Available storage– Available bandwidth, power, …– Keep 90% of response time below X– …• Very hard problem51'),
#  (52,
#   'A very simple model• Single fragment F, m sites• Simple cost model– ti: # retrieval queries from site i– ui: # update queries from site i– Processing cost depends only on type of query and source/target site• No capacity constraints– Processing power, storage, …• Question: Where to store F?– Set 𝐼 ⊆ 1, … , 𝑚 of sites52'),
#  ('53PLAIN',
#   'Read cost (1)53S1 S2.. ....S3SiCi4Ci3Ci1Ci2Stream of readrequests for Fti REQ/SECCi5CiiFF FS4 S5'),
#  ('53OCR',
#   'Read cost (1)\n\nfo ~ Si Stream of read\neo requests for F\nCae t; REQ/SEC\n'),
#  (54,
#   'Read cost (2)• Read where cheapest• Cost: σ𝑖=1𝑚 𝑡𝑖 min𝑗∈𝐼𝐶𝑖𝑗– ti: # retrieval queries from site i– 𝐶𝑖𝑗: cost of processing one retrieval query fromsite i using replica at site j54'),
#  ('55PLAIN', 'Write cost (1)55Updatesui updates/sec. .. .. .SiFF F'),
#  ('55OCR',
#   'Write cost (1)\n\nF NY Updates\n\nLl] _————__ 8\n\nSj u, updates/sec\n\n'),
#  (56,
#   'Write cost (2)• Update all replicas• Cost: σ𝑖=1𝑚 𝑢𝑖 σ𝑗∈𝐼 𝐶𝑖𝑗′– ui: # update queries from site i– 𝐶𝑖𝑗′: cost of processing one update query fromsite i on replica at site j56'),
#  ('57PLAIN',
#   'Storage cost• May differ per site• Cost: σ𝑖∈𝐼 𝑑𝑖– di: cost of storing replica at site i57'),
#  ('57OCR',
#   'Storage cost\ne May differ per site\n° Cost: Vie, di\n—d;: cost of storing replica at site /\n'),
#  (58,
#   'Putting it together• Total cost is sum of individual costs• min𝐼σ𝑖=1𝑚 (𝑡𝑖 min𝑗∈𝐼𝐶𝑖𝑗 + 𝑢𝑖 σ𝑗∈𝐼 𝐶𝑖𝑗′) + σ𝑖∈𝐼 𝑑𝑖• Problem is NP-complete…• … and overly simplified; e.g., in practice– Multiple fragments, multiple relations– Fragment placement / costs not independent– Complex query processing costs – Cost of integrity enforcement– Cost of concurrency control– Dynamics– ….58'),
#  ('59PLAIN', 'Outline1. Basics2. Fragmentation3. Allocation4. Transparency59'),
#  ('59OCR', 'Outline\n1.\n2.\n3.\n4. Transparency\n'),
#  (60,
#   'Transparency• Transparency = separation of high-level semantics from implementation– Hide implementation details from user– Cf.: data independence in RDBMS• Multiple layers– Fragmentation transparency– Allocation transparency– Network transparency60'),
#  (61,
#   'Example# name loc sal5 Joe Sa 107 Sally Sb 258 Tom Sa 15…61# name loc sal5 Joe Sa 108 Tom Sa 15…# name loc sal7 Sally Sb 25…At Sa At SbEE1E2'),
#  ('62PLAIN',
#   'Overview62Global schemaFragmentation schemaAllocation schemaLocalschemaLocalschemaLocalDBMSLocalDBMSLocalDBLocalDBSite 1 Site 2............'),
#  ('62OCR',
#   'Overview\n\nGlobal schema\nFragmentation schema\nAllocation schema\n\nLocal Local\nschema schema\n\n| Local! ! Local!\nI I\nL DBMS 1 i DBMS _|\nI I\na —\nLocal Local\nDB DB\n\n62\n'),
#  ('63PLAIN',
#   'Fragmentation transparency• Queries placed against global schema– Fragmentation and allocation hidden• Example – select #, locfrom Ewhere #=563'),
#  ('63OCR',
#   'Fragmentation transparency\n\n° Queries placed against global schema\n— Fragmentation and allocation hidden\n° Example\n\n— select #, loc\nfrom E\nwhere #=5\n'),
#  (64,
#   'Allocation transparency• Queries placed against fragmentation schema– Applications need to know fragmentation and place their queries against fragments– Allocation still hidden• Example – select #, locfrom E1where #=5• Example: how many employees?– select count(*)from E1 union E264'),
#  (65,
#   'Network transparency• Queries placed against allocation schema– Applications need to know fragmentation and place their queries against fragments– Applications also decide which fragments to use• Example – select #, locfrom E1 at Sawhere #=5• Still some level of transparency– Same data model, same query language– Often not possible when using different DBMS at sites65'),
#  ('66PLAIN', 'Layers of independence66'),
#  ('66OCR', 'Layers of independence\n\n\\ndepengg Ne\nS\n\n66\n'),
#  (67,
#   'Which level of transparency?• Compromise– Ease of use– Stability w.r.t. configuration changes– Ability to control query processing by applications– Difficulty and overhead cost of providing transparency• Choice is application dependent– E.g., full transparency may be poor choice for geographically distributed sites67'),
#  ('68PLAIN',
#   'Outline1. Basics2. Fragmentation 3. Allocation4. Transparency68'),
#  ('68OCR',
#   'Outline\n\n1. Basics\n\nNO\n\n. Fragmentation\n. Allocation\n. Transparency\n\n W\n'),
#  (69,
#   'Literature• Ö/V, Principles of Distributed Database Systems– Ch. 1: Introduction– Ch. 2: Distributed and Parallel Database Design– Ch. 8: Parallel Database Systems• GM/U/W, Database Systems – The CompleteBook– Ch. 20: Parallel and Distributed Databases• W, Advanced Data Management– Ch. 10: Distributed database systems– Ch. 11: Fragmentation• K/E, Datenbanksysteme– Ch. 16: Verteilte Datenbanken69'),
#  ('70PLAIN',
#   'Acknowledgements• Garcia-Molina: Parallel and Distributed Data Management• Kemper: Verteilte Datenbanken70'),
#  ('70OCR',
#   'Acknowledgements\n\n¢ Garcia-Molina: Parallel and Distributed Data\nManagement\n¢ Kemper: Verteilte Datenbanken\n')]

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['afr', 'amh', 'ara', 'asm', 'aze', 'aze_cyrl', 'bel', 'ben', 'bod', 'bos', 'bre', 'bul', 'cat', 'ceb', 'ces', 'chi_sim', 'chi_sim_vert', 'chi_tra', 'chi_tra_vert', 'chr', 'cos', 'cym', 'dan', 'deu', 'div', 'dzo', 'ell', 'eng', 'enm', 'epo', 'equ', 'est', 'eus', 'fao', 'fas', 'fil', 'fin', 'fra', 'frk', 'frm', 'fry', 'gla', 'gle', 'glg', 'grc', 'guj', 'hat', 'heb', 'hin', 'hrv', 'hun', 'hye', 'iku', 'ind', 'isl', 'ita', 'ita_old', 'jav', 'jpn', 'jpn_vert', 'kan', 'kat', 'kat_old', 'kaz', 'khm', 'kir', 'kmr', 'kor', 'kor_vert', 'lao', 'lat', 'lav', 'lit', 'ltz', 'mal', 'mar', 'mkd', 'mlt', 'mon', 'mri', 'msa', 'mya', 'nep', 'nld', 'nor', 'oci', 'ori', 'osd', 'pan', 'pol', 'por', 'pus', 'que', 'ron', 'rus', 'san', 'sin', 'slk', 'slv', 'snd', 'snum', 'spa', 'spa_old', 'sqi', 'srp', 'srp_latn', 'sun', 'swa', 'swe', 'syr', 'tam', 'tat', 'tel', 'tgk', 'tha', 'tir', 'ton', 'tur', 'uig', 'ukr', 'urd', 'uzb', 'uzb_cyrl', 'vie', 'yid', 'yor']

# %%
pdf = pdfium.PdfDocument("./demo_data/02-PDBMS.pdf")
print(pdf.get_page(5).)
# Out:
# <pypdfium2._helpers.page.PdfPage object at 0x1074c5480>
